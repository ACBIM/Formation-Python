# %% [markdown]
# <a href="https://colab.research.google.com/github/ACBIM/Formation-Python/blob/main/Exercices/Manipulation%20de%20donn%C3%A9es.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1> Manipulation de données </h1>
# <p>Comme vu dans le chapitre "Les bases", Python a recours à différents types de représentations pour les données qu'il manipule. Jusqu'ici, nous avons vu les types : entier ou int, string ou str (chaîne de caractères), nombre à virgule ou float.  </p>

# %%
#Pour vérifier le type de la donnée stockée dans une variable, il est possible d'utiliser la fonction type().

maPhrase = "Ceci est une chaîne de caractères"
nombreEntier = 2
nombreVirgule = 2.0
type(nombreEntier)

# %% [markdown]
# <p> Dans ce chapitre, nous verrons qu'il existe des types de données plus complexes et comment les manipuler. </p>

# %%
maListe = ["N'importe quoi", 1, 2, -1, 1, False, "ACDEAU"]

monDictionnaire = {"Auteur1" : "Balzac", "Auteur2" : "Verne", "Auteur3" : "Kafka"}

monTuple = ("Pomme", "Pêche", "Poire", "Abricot", "Pomme")

monSet = {"Pomme", "Pêche", "Poire", "Abricot"}

print(type(maListe))
print(type(monDictionnaire))
print(type(monTuple))
print(type(monSet))
print(len("Test"))

# %% [markdown]
# <h1> Formatage simple d'une chaîne de caractères </h1>
#
# <p>Le formatage d'une chaîne de caractères s'effectue à l'aide de l'opérateur modulo % suivi de la lettre s.</p>

# %%
"Veux-tu la %s %s %s ?" % ("pilule", "bleue", "magique")

# %% [markdown]
# <p> On peut rendre cette expression plus souple à l'aide d'un type de données appelé dictionnaire. Un dictionnaire rattache une "clé" à sa "valeur", de la même manière qu'un vrai dictionnaire associe un mot à sa définition. Ce système est, sans surprise, appelé "clé/valeur". Voyez ci-dessous : </p>

# %%
"Veux-tu la %(objet)s %(couleur)s ?" % {"objet" : "pilule", "couleur" : "bleue"}

# %% [markdown]
# <p> Ce qui peut tout aussi bien s'écrire ainsi : </p>

# %%
"Veux-tu la {} {} ?".format("pilule", "bleue")

# %% [markdown]
# <p> Nous pouvons dès lors manipuler plus aisément la position des variables : </p>

# %%
"Veux-tu la {1} {2} {2} ?".format("pilule", "bleue", "magique")

"Do you want the {1} {0} ?".format("pill", "blue")

# %% [markdown]
# <p> De même qu'il est possible de nommer les arguments. </p>

# %%
"Veux-tu la {objet} {couleur} ?".format(objet="pilule", couleur="bleue")

# %% [markdown]
# <h1> Exercice : formater un mail </h1>

# %%
#À partir de la liste de clients ci-dessous, proposez un programme permettant de formater un mail personnalisé selon chacun des destinataires.
destinataire1 = {"denomination" : "Madame", "nom" : "Iphigénie"}
destinataire2 = {"denomination" : "Monsieur", "nom" : "Hercule"}

listeDestinataires= [destinataire1, destinataire2]

listeMails = []
for destinataires in listeDestinataires:
    newMail = "%(denomination)s %(nom)s,  " \
    "Veuillez trouver ci-joint le catalogue de notre nouvelle collection de superbes regards béton pour l'année 2026."% destinataires
    listeMails.append(newMail)


print(listeMails)

# %% [markdown]
# <p> Toujours dans l'esprit du formatage, il existe des fonctions pour modifier la casse d'une chaîne de caractères. </p>

# %%
maPhrase = "CeCi Est UNE CHAîNe dE CarActèRES"
maPhraseEnMinsuscules = maPhrase.lower()
maPhraseEnMajuscules = maPhrase.upper()
print(maPhraseEnMinsuscules, "en miniscules")
print(maPhraseEnMajuscules, "EN MAJUSCULES")

#De même :

print(maPhrase.capitalize())
print(maPhrase.title())
print(maPhrase.swapcase())

# %% [markdown]
# <h1> Notion de longueur </h1>

# %%
#Nous pouvons obtenir la longueur d'une chaîne avec la méthode suivante :
alphabet = "Abcdefghijklmnopqrstuvwxyz"
alphabetEspace = "Abcdefghijkl mnopqrstuvwxyz"
longueur = len(alphabet)
longueur2 = len(alphabetEspace)
print(longueur)
print(longueur2)

# %% [markdown]
# <h1> Notion d'appartenance </h1>

# %%
#Voici comment savoir si une chaîne de caractères en contient une autre :
phrase = "Cette phrase cache un secret."

#Mot recherché dans la phrase
mot = "secret"
print(mot in phrase)

# %% [markdown]
# <h1>Notion d'occurrence </h1>

# %%
#Ci-dessous, une méthode pour comptabiliser l'occurrence d'un caractère ou plus dans une chaîne.

chaine = "Abrakadabra, Alakazam"

print(chaine.count('a'))
print(chaine.lower().count("ab"))

# %% [markdown]
# <h1> Notion d'index </h1>
# <p> En python, une chaîne est systématiquement indexée : la position de chacun de ses caractères est identifiable par un indice, allant de 0 (première position) à n (dernière position). Cette indexation peut également s'utiliser dans le sens négatif : ainsi, le dernier élément a aussi l'indice -1, le pénultième -2, etc. </p>

# %%
chaine = "Alakazam"

#Permet d'obtenir la position de la première occurence du caractère dans la chaîne.
position = chaine.index('a')
print(position)

#Pour trouver la position de l'occurrence suivante :

position2 = chaine.index('a', position + 1)
print(position2)

# %% [markdown]
# <h1> Notions imoprtantes : définition d'une fonction, boucle for </h1>
# <p> Exercice : nous voudrions pouvoir obtenir les positions de l'ensemble des occurrences d'un caractère donné. En partant de l'exemple de la cellule précédente, écrire un algorithme qui répond à nos attentes : </p>

# %%
#Commençons par définir notre propre fonction
#Celle-ci prendra deux paramètres : la chaîne de caractères étudiée et l'élément dont nous voulons extraire la position des occurrences.
def positions(chaine, element) :
    #On initialise la position à -1 afin de pouvoir commencer la recherche à 0, puisqu'on utilise position + 1.
    position = -1
    #On comptabilise le nombre d'occurrences de l'élément recherché : les instructions ci-dessous se répèteront autant de fois qu'il y a d'occurrences
    for i in range(chaine.count(element)):
        position = chaine.index(element, position + 1)
        print("position de l'occurrence numéro {} : {}".format(i + 1, position))


#Enfin, nous pouvons appeler notre fonction en la paramétrant comme souhaité.

positions("Abrakadabra, Alakazam", "a")
positions("ACDEAU, ACBIM", "AC")

# %% [markdown]
# <p> Reprenons les notions vues dans l'exemple ci-dessus une à une. </p>
# <p> 1. Définition d'une fonction : </p>
#  <p>Se fait à l'aide du mot-clé def. Définir une fonction permet de réutiliser les instructions contenues dans cette dernière au moment souhaité. Cela permet d'organiser au mieux notre code et de ne pas surcharger notre programme.
# </p>

# %%
#Écrivons une fonction permettant à l'utilisateur de calculer la somme de deux nombres.

def afficherSomme(nombre1, nombre2):
    resultat = nombre1 + nombre2
    print(resultat)

#La fonction une fois définie, il devient possible de l'appeler



#Le mot-clé return permet de renvoyer effectivement la valeur du résultat, restant en mémoire.
def calculSomme(nombre1, nombre2):
    resultat = nombre1 + nombre2
    return resultat

somme1 = afficherSomme(10, 20)
print(somme1)

# %% [markdown]
# <p>2. Bloc itératif avec la boucle for, méthode range() : </p>
# <p> L'utilisation de la boucle for est similaire à while tel que mentionné dans le chapitre "Les bases". Seulement, l'usage de for permet le contrôle sur le nombre d'itérations désiré, là où while répète les instructions autant de fois qu'une condition est remplie ou non. </p>

# %%
for i in range(0, 10):
    print(i)


#Pour insérer un espace :
print("\n")

for i in range(0, 11, 2):
    print(i)

# %% [markdown]
# <p> La boucle for est très pratique - elle permet par exemple de parcourir une liste. </p>

# %%
listeClients = ["Bonaparte", "Zedong", "Attila", "Khan", "Caesar"]

for client in listeClients :
    print(client)

# %% [markdown]
# <h1>Les listes en Python (arrays)</h1>
# <p> 1. Les listes figurent parmi ce qu'on appelle les collections ou arrays en Python. Ce sont des objets particuliers qui permettent de stocker - vous l'aurez deviné - des collections de données : des nombres entiers, des chaînes de caractères, des booléens, d'autres listes (oui, il est possible de générer une liste de listes)... En bref, une liste peut stocker tout type de donnée prédéfinie par le langage. Elle est indexée de 0 à n, où n est la longeur de la liste. Une liste est modifiable, ses éléments peuvent être supprimés ou interchangés, et l'on peut naturellement y ajouter de nouvelles données.  Voyons comment manipuler ce type d'objet : </p>

# %%
#Une liste est définie avec des crochets ou avec list().
listeClients = ["Bonaparte", "Zedong", "Attila", "Khan", "Caesar"]
listeClients2 = list(("Louis XIV", "Saladin", "Tepes", "Thémistocle"))

#Elle peut recevoir des types de données tout à fait différents :
listeDonnees = ["Chaine", True, 20.3, 450, listeClients, ["ACDEAU", "ACBIM"]]

#On peut aussi initialiser une liste vide :
liste_a_completer = []


#On accède possiblement aux différents éléments de la liste par leur index, précisé entre crochets suivant le nom de la variable :
#Ici, on affiche le tout premier élément de listeClients, à savoir "Bonaparte"
print(listeClients[0])


#Pour ajouter un élément à la fin d'une liste :
liste_a_completer.append("Néron")
#On peut aussi placer directement un élément via l'index :
liste_a_completer[0] = "Octave"
#Cela a pour effet de substituer la valeur qui se trouvait précédemment à cet emplacement : on aura remplacé "Néron" par "Octave".

#Si l'on veut ajouter un élément à la liste sans remplacer la donnée présente à un index donné, il est possible d'utiliser la méthode insert()
liste_a_completer.insert(0, "Néron")
print(liste_a_completer)
#Ainsi "Néron" est inséré à l'index 0, et "Octave" prendra 1 pour index (décalé vers la droite dans la liste).


#Pour enlever un élément de la liste :
listeClients.remove("Caesar")
print(listeClients)

#Pour enlever le dernier élément de la liste :
listeClients2.pop()
print(listeClients2)

#Transformer une chaîne de caractères en liste :
citation = "Demain dès l'aube, à l'heure où blanchit la campagne..."
#La fonction split peut prendre un paramètre purement optionnel indiquant le séparateur.
citationDecoupee = citation.split(sep=" ")
print(citationDecoupee)

# %% [markdown]
# <h1> Exercices : manipulations de listes </h1>

# %% [markdown]
# <p> Vous l'aurez compris, Python propose une myriade de fonctions permettant de manipuler les listes. À partir des exemples précédents, essayons de résoudre les problèmes suivants : </p>

# %% [markdown]
# <p> 1. De retour d'un levé topographique, l'export de la liste des points s'est mal déroulé : il ne reste du fichier qu'une masse confuse. Inspirez-vous des méthodes vues dans la section précédente pour réassembler la donnée sous forme de liste cohérente :  </p>

# %%
listingPoints = "Point1,ERREUR1500.25,2324.32,555.14,Point2,ERREUR1516.12,2346.47,554.89,Point3,ERREUR1565.34,2375.36,542.19"

listingCorrige = listingPoints.replace("ERREUR", "")
print(listingCorrige)
listingFinal = listingCorrige.split(sep=",")
print(listingFinal)

# %% [markdown]
# <p>2. Suite à une erreur en base de données, la liste de nos clients s'est retrouvée entremêlée avec un listing de montants de facturation. Rédigez un programme permettant de séparer les deux listes :  </p>

# %%
listingMelange = ["Orlok", 12500, "Dracula", 320, "Vlad l'Empaleur", 1400, "Bathory", 4780]

#Indice : combiner une boucle for avec la fonction range()...

# %% [markdown]
# <h1> Écrire, modifier un fichier en Python </h1>

# %% [markdown]
# <p> Nous avons vu comment manipuler des données propres au langage Python. Il faut cependant savoir que Python est capable d'agir directement sur des fichiers. Voyons comment se présente la chose. </p>

# %%
#Ouvrir un fichier existant :
#Il nous faut préciser le chemin relatif ou absolu du fichier dans le paramètre de la fonction open()
path = "C:/Users/BimP05/Documents/formationPython/notebook/Exercices/ressources/listingCoordonnees"
path2 = "C:/Users/BimP05/Documents/formationPython/notebook/Exercices/ressources/listingCoordonnees copy"
#Si l'on souhaite modifier le contenu du fichier, il faudra ajouter l'option "w" (pour "write")
with open(path, "w") as f:
    test = "Contenu du fichier numéro 1"
    f.write(test)

#Notez que le programme ci-dessus a pour effet de substituer entièrement le contenu préexistant du fichier.
#Si l'on veut simplement ajouter du contenu à la suite de la donnée préexistante, il faut utiliser
#  l'option "a" (pour append) dans open():

with open(path2, "a") as f2:
    test = "Contenu du fichier numéro 2"
    f2.write("\n" + test)

#On peut aussi concaténer le contenu de deux fichiers dans un fichier tiers :
#Utilisons open() avec la fonction "r" (pour "read")
fichier1 = open(path, "r")
fichier2 = open(path2, "r")

#On stocke le contenu des deux fichiers
contenuFichier1 = fichier1.read()
contenuFichier2 = fichier2.read()

#On utilise la méthode .close() afin de s'assurer que la ressource n'est plus utilisée
fichier1.close
fichier2.close

pathVersLeFichierFinal = "C:/Users/BimP05/Documents/formationPython/notebook/Exercices/ressources/listingFusionne"
#On souhaite écrire dans le fichier, on utilisera donc l'option "w"
with open(pathVersLeFichierFinal, "w") as f3:
    f3.write(contenuFichier1 + "\n" + contenuFichier2)

# %% [markdown]
# <h1> Manipuler des extensions de fichiers particulières </h1>
# <p> Les fichiers vus jusqu'à présent portaient simplement l'extension .txt. Sachez cependant qu'il existe des fonctionnalités de Python permettant d'effectuer des traitements sur d'autres types de fichiers, tels que .csv ou .JSON. </p>

# %% [markdown]
# <p> Il nous faut pour ce faire importer des fonctionnalités spécialisées à partir de ce qu'on appelle une bibliothèque.</p>

# %% [markdown]
# <h1> Notion importante : installation d'une bibliothèque et importation des fonctionnalités </h1>

# %%
#L'import des fonctionnalités d'une bibliothèque se fait comme suit :
#
# numpy est une bibliothèque conçue pour traiter des matrices et des tableaux.
import numpy
#Sans surprise, csv contient des fonctionnalités qui nous aideront à manipuler les fichiers du même nom
import csv
#idem pour json
import json


#Il nous est désormais possible d'accéder aux méthodes de chacune des bibliothèques importées avec "."

csv.reader()
json.load()
numpy.average()

# %% [markdown]
# <p> Certaines bibliothèques (ou modules) ne viennent pas directement avec notre installation de Python. Il nous faudra alors installer la bibliothèque recherchée, par exemple à l'aide d'un gestionnaire de paquets. Ici, nous utiliserons "pip", mais "conda" demeure une option envisageable. Pour installer un module à l'aide du gestionnaire de paquets, il suffit d'ouvrir un terminal et de lancer la commande :  </p>

# %% [markdown]
# <p> pip install nomDuProgramme </p>
#
# <p> Essayons par exemple la bibliothèque matplotlib, très utile pour réaliser des graphiques. </p>

# %%
import matplotlib.pyplot as plt

coordonnéesX = [1000, 1050, 1010, 1020, 1000]
coordonnéesY = [2500, 2001, 2043, 2056, 2500]
plt.plot(coordonnéesX, coordonnéesY)
plt.xlabel('Coord. E')
plt.ylabel('Coord. N')
plt.title('Cheminement polygonal')
plt.show()
