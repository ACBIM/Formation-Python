# %% [markdown]
# <a href="https://colab.research.google.com/github/ACBIM/Formation-Python/blob/main/Exercices/Pour%20aller%20plus%20loin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Pour aller plus loin</h1>
# <p> Ce qui a été présenté ici ne constitue qu'une maigre goutte dans un océan de possibiltés.
#  Voici quelques pistes pour vous lancer dans l'exploration du langage Python :
#  </p>

# %% [markdown]
# <p> La cybersécurité, dont la cryptographie : voir les différents algorithmes de chiffrement (sha, md5...), cf. bibliothèque hashlib
#
# Les applications Web (front-end, back-end) avec Pyramid, Django...
#
# Les bases de données (PostgreSQL, MySQL, MongoDB...).
#
# Les applications graphiques (Avec GTK, PyQT)
#
# Les jeux vidéos (PyGame)
#
# </p>
